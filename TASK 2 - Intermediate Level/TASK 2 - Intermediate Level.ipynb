# %% [markdown]
# # LETSGROWMORE
# # lgmvip
# ## Data Science and Data Analytics Internship.
# ### Task 2 : Prediction using Decision Tree  Algorithm
# ### Dataset : Iris.csv
# -----------------------------------------------------------------------------------------

# %% [markdown]
# # Task : Create the Decision Tree classifier and visualize it graphically. The purpose is if we feed any new data to this classifier, it would be able to  predict the right class accordingly
#
# ## By : Isha Patel

# %% [markdown]
# # Importing necessary libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the dataset

# %%
df = pd.read_csv('IRIS.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Data Explorating

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# > the above funcations are displaying the basic statistical summary and infomation about the dataset
#
# > also checking if any nuull values are present in the dataset

# %% [markdown]
# # Data Visualization using relplot and heatmap

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# %%
# Plot correlation matrix as a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Create a pair plot using pairplot
sns.set(style="ticks")  # Set the style of the plot
sns.pairplot(df, hue="species", palette="Set3")
# Add a title
plt.suptitle("Pair Plot of Iris Dataset")
# Show the plot
plt.show()

# %%
# Create a scatter plot using relplot
sns.set(style="whitegrid")  # Set the style of the plot
sns.relplot(x="sepal_length", y="sepal_width", hue="species", data=df, palette="Set1", kind="scatter")
# Add a title
plt.title("Sepal Length vs Sepal Width")
# Show the plot
plt.show()

# %%
# Create a scatter plot using relplot
sns.set(style="whitegrid")  # Set the style of the plot
sns.relplot(x="petal_length", y="sepal_width", hue="species", data=df, palette="Set2", kind="scatter")
# Add a title
plt.title("Petal Length vs Sepal Width")
# Show the plot
plt.show()

# %%
# Create a scatter plot using relplot
sns.set(style="whitegrid")  # Set the style of the plot
sns.relplot(x="sepal_length", y="petal_width", hue="species", data=df, palette="Set3", kind="scatter")
# Add a title
plt.title("Sepal Length vs Petal Width")
# Show the plot
plt.show()

# %%
# Create a scatter plot using relplot
sns.set(style="whitegrid")  # Set the style of the plot
sns.relplot(x="petal_length", y="petal_width", hue="species", data=df, palette="Set1", kind="scatter")
# Add a title
plt.title("Petal Length vs Petal Width")
# Show the plot
plt.show()

# %% [markdown]
# # Spliting the dataset into X and y and applying train_test_split

# %%
# Assuming that your feature columns are 'sepal_length', 'sepal_width', 'petal_length', and 'petal_width'
X_columns = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
X = X_columns
# Assuming that your target column is 'species'
y = df[['species']]

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 81            5.5          2.4           3.7          1.0
# 133           6.3          2.8           5.1          1.5
# 137           6.4          3.1           5.5          1.8
# 75            6.6          3.0           4.4          1.4
# 109           7.2          3.6           6.1          2.5
# ..            ...          ...           ...          ...
# 71            6.1          2.8           4.0          1.3
# 106           4.9          2.5           4.5          1.7
# 14            5.8          4.0           1.2          0.2
# 92            5.8          2.6           4.0          1.2
# 102           7.1          3.0           5.9          2.1
#
# [105 rows x 4 columns]

# %%
y_train
# Out:
#              species
# 81   Iris-versicolor
# 133   Iris-virginica
# 137   Iris-virginica
# 75   Iris-versicolor
# 109   Iris-virginica
# ..               ...
# 71   Iris-versicolor
# 106   Iris-virginica
# 14       Iris-setosa
# 92   Iris-versicolor
# 102   Iris-virginica
#
# [105 rows x 1 columns]

# %% [markdown]
# # Applying Decision Tree classifier

# %%
# Create a Decision Tree classifier
clf = DecisionTreeClassifier(max_depth=3)  # Limit the maximum depth
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# Visualize the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=clf.classes_, filled=True)
plt.show()

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
# Make predictions on the test data
y_pred = clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
